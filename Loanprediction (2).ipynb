# %%
#!pip install scikit-learn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    APP_ID   CIBIL_SCORE_VALUE  NEW_CUST  CUS_CATGCODE    EMPLOYMENT_TYPE
# 0   12345                    0      YES              1                  0  \
# 1   12347                    0       NO              1                  1
# 2   12349                    0      YES              1                  0
# 3   12351                    2       NO              1                  1
# 4   12353                    2       NO              1                  1
#
#    AGE  SEX     NO_OF_DEPENDENTS    MARITAL    EDU_QUA    P_RESTYPE
# 0   31      F                   3          0         0             1  \
# 1   40      F                   2          1         1             0
# 2   27      F                   3          0         0             1
# 3   33      M                   2          0         1             0
# 4   29      F                   1          0         1             1
#
#     P_CATEGORY    EMPLOYEE_TYPE     MON_IN_OCC    INCOM_EXP_GMI        LTV
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299 entries, 0 to 13298
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   APP_ID               13299 non-null  int64
#  1    CIBIL_SCORE_VALUE   13299 non-null  int64
#  2   NEW_CUST             13299 non-null  object
#  3   CUS_CATGCODE         13299 non-null  int64
#  4    EMPLOYMENT_TYPE     13299 non-null  int64
#  5   AGE                  13299 non-null  int64
#  6    SEX                 13299 non-null  object
#  7    NO_OF_DEPENDENTS    13299 non-null  int64
#  8    MARITAL             13299 non-null  int64
#  9    EDU_QUA             13299 non-null  int64
#  10    P_RESTYPE          13299 non-null  int64
#  11   P_CATEGORY          13299 non-null  int64
#  12   EMPLOYEE_TYPE       13299 non-null  int64
#  13    MON_IN_OCC         13299 non-null  int64
#  14   INCOM_EXP_GMI       13299 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# APP_ID                 0
#  CIBIL_SCORE_VALUE     0
# NEW_CUST               0
# CUS_CATGCODE           0
#  EMPLOYMENT_TYPE       0
# AGE                    0
#  SEX                   0
#  NO_OF_DEPENDENTS      0
#  MARITAL               0
#  EDU_QUA               0
#   P_RESTYPE            0
#  P_CATEGORY            0
#  EMPLOYEE_TYPE         0
#   MON_IN_OCC           0
#  INCOM_EXP_GMI         0
# LTV                    0
#  TENURE                0
# STATUS                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['APP_ID', ' CIBIL_SCORE_VALUE ', 'NEW_CUST', 'CUS_CATGCODE ',
#        ' EMPLOYMENT_TYPE ', 'AGE', ' SEX  ', ' NO_OF_DEPENDENTS ', ' MARITAL ',
#        ' EDU_QUA', '  P_RESTYPE ', ' P_CATEGORY ', ' EMPLOYEE_TYPE ',
#        '  MON_IN_OCC ', ' INCOM_EXP_GMI ', 'LTV', ' TENURE ', 'STATUS'],
#       dtype='object')

# %%
for i in df:
  if df[i].dtype == 'object':
    print(i)
# Out:
# NEW_CUST
#  SEX

# %%
###df['NEW_CUST'] = pd.to_numeric(df['NEW_CUST'],errors = 'coerce')
###df[' SEX  '] = pd.to_numeric(df[' SEX  '],errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299 entries, 0 to 13298
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   APP_ID               13299 non-null  int64
#  1    CIBIL_SCORE_VALUE   13299 non-null  int64
#  2   NEW_CUST             13299 non-null  object
#  3   CUS_CATGCODE         13299 non-null  int64
#  4    EMPLOYMENT_TYPE     13299 non-null  int64
#  5   AGE                  13299 non-null  int64
#  6    SEX                 13299 non-null  object
#  7    NO_OF_DEPENDENTS    13299 non-null  int64
#  8    MARITAL             13299 non-null  int64
#  9    EDU_QUA             13299 non-null  int64
#  10    P_RESTYPE          13299 non-null  int64
#  11   P_CATEGORY          13299 non-null  int64
#  12   EMPLOYEE_TYPE       13299 non-null  int64
#  13    MON_IN_OCC         13299 non-null  int64
#  14   INCOM_EXP_GMI       13299 non-null  int64
# ...

# %%
data_frame = pd.DataFrame(df, columns=['SEX', 'NEW_CUST'])
print(data_frame)
# Out:
#        SEX NEW_CUST
# 0      NaN      YES
# 1      NaN       NO
# 2      NaN      YES
# 3      NaN       NO
# 4      NaN       NO
# ...    ...      ...
# 13294  NaN      YES
# 13295  NaN       NO
# 13296  NaN      YES
# 13297  NaN      YES
# 13298  NaN       NO
#
# [13299 rows x 2 columns]

# %%
df_one = pd.get_dummies(df[[' SEX  ', 'NEW_CUST']])
print(df_one)
# Out:
#         SEX  _F   SEX  _M  NEW_CUST_NO  NEW_CUST_YES
# 0          True     False        False          True
# 1          True     False         True         False
# 2          True     False        False          True
# 3         False      True         True         False
# 4          True     False         True         False
# ...         ...       ...          ...           ...
# 13294     False      True        False          True
# 13295      True     False         True         False
# 13296      True     False        False          True
# 13297      True     False        False          True
# 13298      True     False         True         False
#
# [13299 rows x 4 columns]

# %%
df_new = pd.concat([df,df_one],axis=1)

# %%
df_new.head()
# Out:
#    APP_ID   CIBIL_SCORE_VALUE  NEW_CUST  CUS_CATGCODE    EMPLOYMENT_TYPE
# 0   12345                    0      YES              1                  0  \
# 1   12347                    0       NO              1                  1
# 2   12349                    0      YES              1                  0
# 3   12351                    2       NO              1                  1
# 4   12353                    2       NO              1                  1
#
#    AGE  SEX     NO_OF_DEPENDENTS    MARITAL    EDU_QUA    P_RESTYPE
# 0   31      F                   3          0         0             1  \
# 1   40      F                   2          1         1             0
# 2   27      F                   3          0         0             1
# 3   33      M                   2          0         1             0
# 4   29      F                   1          0         1             1
#
#     P_CATEGORY    EMPLOYEE_TYPE     MON_IN_OCC    INCOM_EXP_GMI        LTV
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299 entries, 0 to 13298
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   APP_ID               13299 non-null  int64
#  1    CIBIL_SCORE_VALUE   13299 non-null  int64
#  2   NEW_CUST             13299 non-null  object
#  3   CUS_CATGCODE         13299 non-null  int64
#  4    EMPLOYMENT_TYPE     13299 non-null  int64
#  5   AGE                  13299 non-null  int64
#  6    SEX                 13299 non-null  object
#  7    NO_OF_DEPENDENTS    13299 non-null  int64
#  8    MARITAL             13299 non-null  int64
#  9    EDU_QUA             13299 non-null  int64
#  10    P_RESTYPE          13299 non-null  int64
#  11   P_CATEGORY          13299 non-null  int64
#  12   EMPLOYEE_TYPE       13299 non-null  int64
#  13    MON_IN_OCC         13299 non-null  int64
#  14   INCOM_EXP_GMI       13299 non-null  int64
# ...

# %%
df_new.replace({False: 0, True: 1}, inplace=True)

# %%
df_new
# Out:
#        APP_ID   CIBIL_SCORE_VALUE  NEW_CUST  CUS_CATGCODE    EMPLOYMENT_TYPE
# 0       12345                    0      YES              1                  0  \
# 1       12347                    0       NO              1                  1
# 2       12349                    0      YES              1                  0
# 3       12351                    2       NO              1                  1
# 4       12353                    2       NO              1                  1
# ...       ...                  ...      ...            ...                ...
# 13294   38933                    0      YES              1                  0
# 13295   38935                    2       NO              1                  1
# 13296   38937                    0      YES              1                  1
# 13297   38939                    0      YES              1                  1
# 13298   38941                    2       NO              1                  1
#
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299 entries, 0 to 13298
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   APP_ID               13299 non-null  int64
#  1    CIBIL_SCORE_VALUE   13299 non-null  int64
#  2   NEW_CUST             13299 non-null  object
#  3   CUS_CATGCODE         13299 non-null  int64
#  4    EMPLOYMENT_TYPE     13299 non-null  int64
#  5   AGE                  13299 non-null  int64
#  6    SEX                 13299 non-null  object
#  7    NO_OF_DEPENDENTS    13299 non-null  int64
#  8    MARITAL             13299 non-null  int64
#  9    EDU_QUA             13299 non-null  int64
#  10    P_RESTYPE          13299 non-null  int64
#  11   P_CATEGORY          13299 non-null  int64
#  12   EMPLOYEE_TYPE       13299 non-null  int64
#  13    MON_IN_OCC         13299 non-null  int64
#  14   INCOM_EXP_GMI       13299 non-null  int64
# ...

# %%
df_new.drop(columns=[' SEX  ','NEW_CUST'],axis =1 ,inplace =True)

# %%
df_new.head()
# Out:
#    APP_ID   CIBIL_SCORE_VALUE   CUS_CATGCODE    EMPLOYMENT_TYPE   AGE
# 0   12345                    0              1                  0   31  \
# 1   12347                    0              1                  1   40
# 2   12349                    0              1                  0   27
# 3   12351                    2              1                  1   33
# 4   12353                    2              1                  1   29
#
#     NO_OF_DEPENDENTS    MARITAL    EDU_QUA    P_RESTYPE    P_CATEGORY
# 0                   3          0         0             1             4  \
# 1                   2          1         1             0             1
# 2                   3          0         0             1             2
# 3                   2          0         1             0             2
# 4                   1          0         1             1             2
#
#     EMPLOYEE_TYPE     MON_IN_OCC    INCOM_EXP_GMI        LTV   TENURE
# ...

# %%
x = df_new.drop(columns = ['STATUS'],axis=1)
y = df_new['STATUS']

# %%
(X_train, X_test , Y_train ,Y_test) = train_test_split(x,y,test_size = 0.3,random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
y_pred=logistic.predict(X_test)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]
# c:\Users\Himanshu\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
score=accuracy_score(y_pred,Y_test)
print(score)
print(classification_report(y_pred,Y_test))
print(confusion_matrix(y_pred,Y_test))
# Out:
# 0.62531328320802
#               precision    recall  f1-score   support
#
#            0       0.92      0.64      0.75      3565
#            1       0.15      0.52      0.23       425
#
#     accuracy                           0.63      3990
#    macro avg       0.53      0.58      0.49      3990
# weighted avg       0.84      0.63      0.70      3990
#
# [[2272 1293]
#  [ 202  223]]

# %% [markdown]
# Hyperparameter Tuning And Cross Validation
# Grid SearchCV

# %%
model=LogisticRegression()
penalty=['l1', 'l2', 'elasticnet']
c_values=[100,10,1.0,0.1,0.01]
solver=['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']

# %%
params=dict(penalty=penalty,C=c_values,solver=solver)

# %%
from sklearn.model_selection import StratifiedKFold
cv=StratifiedKFold()

# %%
from sklearn.model_selection import StratifiedKFold
cv=StratifiedKFold()

# %%
## GridSearchCV
from sklearn.model_selection import GridSearchCV

grid=GridSearchCV(estimator=model,param_grid=params,scoring='accuracy',cv=cv,n_jobs=-1)

# %%
grid
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [100, 10, 1.0, 0.1, 0.01],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              scoring='accuracy')

# %%
grid.fit(X_train,Y_train)
# Out:
# c:\Users\Himanshu\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 200 fits failed out of a total of 375.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Himanshu\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Himanshu\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
grid.best_params_
# Out:
# {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
grid.best_score_
# Out:
# 0.6464698823900158

# %%
y_pred=grid.predict(X_test)

# %%
score=accuracy_score(y_pred,Y_test)
print(score)
print(classification_report(y_pred,Y_test))
print(confusion_matrix(y_pred,Y_test))
# Out:
# 0.6401002506265664
#               precision    recall  f1-score   support
#
#            0       0.88      0.66      0.75      3320
#            1       0.25      0.56      0.34       670
#
#     accuracy                           0.64      3990
#    macro avg       0.56      0.61      0.55      3990
# weighted avg       0.77      0.64      0.68      3990
#
# [[2179 1141]
#  [ 295  375]]

# %%
X = df_new.drop('STATUS',axis=1)
y = df_new['STATUS']

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
#model_val(model,X,y)

rf = RandomForestClassifier(n_estimators=270,
 min_samples_split=5,
 min_samples_leaf=5,
 max_features='sqrt',
 max_depth=5)

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=5,
#                        n_estimators=270)

# %%
import pickle
filename = 'RandomForestClassifier.model'
with open(filename, 'wb') as file:
    pickle.dump(RandomForestClassifier, file)

# %%
# load the model 
load_model = pickle.load(open(filename, 'rb')) 
  

print(load_model)
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
