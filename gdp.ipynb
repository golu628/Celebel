# %% [markdown]
# <a href="https://colab.research.google.com/github/golu628/Celebel/blob/main/gdp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/gdpWorld.csv')

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
for i in df:
  if df[i].dtype == 'object':
    print(i)
# Out:
# Country
# Region
# Pop. Density (per sq. mi.)
# Coastline (coast/area ratio)
# Net migration
# Infant mortality (per 1000 births)
# Literacy (%)
# Phones (per 1000)
# Arable (%)
# Crops (%)
# Other (%)
# Climate
# Birthrate
# Deathrate
# Agriculture
# Industry
# Service

# %%
for i in df:
  if df[i].dtype == 'object':
    df[i] = pd.to_numeric(df[i],errors = 'coerce')

# %%
df.head()
# Out:
#    Country  Region  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      NaN     NaN  31056997.0       647500.00                         NaN
# 1      NaN     NaN   3581655.0        28748.00                         NaN
# 2      NaN     NaN  32930091.0      1097556.25                         NaN
# 3      NaN     NaN     57794.0          199.00                         NaN
# 4      NaN     NaN     71201.0          468.00                         NaN
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                           NaN            NaN
# 1                           NaN            NaN
# 2                           NaN            NaN
# 3                           NaN            NaN
# 4                           NaN            NaN
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                                 NaN               700.0           NaN
# 1                                 NaN              4500.0           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             0 non-null      float64
#  1   Region                              0 non-null      float64
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          0 non-null      float64
#  5   Coastline (coast/area ratio)        0 non-null      float64
#  6   Net migration                       63 non-null     float64
#  7   Infant mortality (per 1000 births)  4 non-null      float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        0 non-null      float64
#  10  Phones (per 1000)                   0 non-null      float64
# ...

# %%
def outlier_thresholds(dataframe, col_name, q1=0.25, q3=0.75):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

# %%
for i in df.columns:
    low, up = outlier_thresholds(df, i)
    df[i] = np.where(df[i] > up, up, df[i])
    df[i] = np.where(df[i] < low, low, df[i])
    print("the outliers are", i, low, up)
# Out:
# the outliers are Country nan nan
# the outliers are Region nan nan
# the outliers are Population -25152598.75 43087995.25
# the outliers are Area (sq. mi.) -651097.75 1097556.25
# the outliers are Pop. Density (per sq. mi.) nan nan
# the outliers are Coastline (coast/area ratio) nan nan
# the outliers are Net migration 0.0 0.0
# the outliers are Infant mortality (per 1000 births) -59.75 174.25
# the outliers are GDP ($ per capita) -18800.0 36400.0
# the outliers are Literacy (%) nan nan
# the outliers are Phones (per 1000) nan nan
# the outliers are Arable (%) -30.0 50.0
# the outliers are Crops (%) 0.0 0.0
# the outliers are Other (%) 37.5 137.5
# the outliers are Climate 0.5 4.5
# the outliers are Birthrate 8.5 28.5
# the outliers are Deathrate 22.0 22.0
# the outliers are Agriculture 0.0 0.0
# the outliers are Industry nan nan
# the outliers are Service nan nan

# %%
df.head()
# Out:
#    Country  Region  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      NaN     NaN  31056997.0       647500.00                         NaN
# 1      NaN     NaN   3581655.0        28748.00                         NaN
# 2      NaN     NaN  32930091.0      1097556.25                         NaN
# 3      NaN     NaN     57794.0          199.00                         NaN
# 4      NaN     NaN     71201.0          468.00                         NaN
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                           NaN            NaN
# 1                           NaN            NaN
# 2                           NaN            NaN
# 3                           NaN            NaN
# 4                           NaN            NaN
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                                 NaN               700.0           NaN
# 1                                 NaN              4500.0           NaN
# ...
